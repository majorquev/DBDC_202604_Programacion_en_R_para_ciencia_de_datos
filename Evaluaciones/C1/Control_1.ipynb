# %% [markdown]
# <a href="https://colab.research.google.com/github/majorquev/DBDC_202604_Programacion_en_R_para_ciencia_de_datos/blob/main/Evaluaciones/C1/Control_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pauta Control 1: Sintaxis básica y manipulación de objetos simples en R

# %% [markdown]
# Nombre 1: _Puede incluir su nombre acá haciendo doble click_                                                                                                                                      <br>
# Nombre 2: _Puede incluir su nombre acá haciendo doble click_
#
# # Instrucciones
#
# El siguiente test podrá desarrollarlo de manera individual o en pareja con otro(a) de sus compañeros(as).<br>
#
# Lea atentamente cada una de las preguntas propuestas y sea claro en los comentarios (si es que los incluye) de los desarrollos de sus respuestas. Para el desarrollo de las mismas, dispone de celdas de código después de cada pregunta. Sin embargo podrá agregar más celdas si así lo estima conveniente.<br>
# Las preguntas formuladas en este test pueden ser abordadas con las herramientas trabajadas en clases, sin embaro, usted podrá hacer uso de las funcionalidades y/o packages que estime convenientes, a menos que se indique explícitamente lo contrario.
#
# ## Tiempo y entrega
# Dispondrán hasta el día jueves **14 de Mayo** hasta las 23:59 hrs para hacer envío de sus respuestas.
# Una vez finalizado el desarrollo del test, deberá entregarlo teniendo en cuenta las siguientes consideraciones :
#
#  * Descargue el notebook en **formato `*.ipynb`** (uno por pareja), e indique en el nombre del archivo los nombres de los integrantes, `Control1_nombres_integrantes.ipynb`.
#
#  * En caso de trabajar en Rstudio, deberá enviar el script de extensión `*.R` con el siguiente nombre: `Control1_nombres_integrantes.R` , **procurando indicar con comentarios claros, qué pregunta está respondiendo en cada caso**.
#  * Envíe el archivo al correo rumorale1@gmail.com, con copia a majorquev@gmail.com con el asunto "DBDC-R-C1: 'nombre y apellido de los integrantes' "
#
# **NOTA**:
#    * Los correos cuyo asunto no comiencen con "DBDC-R-C1" no llegarán a destino y por ende no serán calificados.
#    * Los archivos que no contengan nombre serán calificados con la nota mínima 1.0.
#    * Los correos enviados posterior a la fecha y hora de entrega indicados tendrán una penalización de 1 punto por día (o fracción) de retraso en la entrega, por ejemplo, si usted envía sus respuestas a las 00:05 hrs del viernes 15 de Mayo, su nota máxima será un 6.0.

# %% [markdown]
# ## Lectura de datos
#
# La siguiente celda permite cargar un objeto con extensión `*.rds` directo desde su directorio de trabajo. Para ello, asegúrese de que el archivo llamado datos_ventas.rds se encuentre en su WD, de lo contrario, modifique la ruta de la siguiente celda para cargar correctamente el archivo.

# %%
ventas <- readRDS("datos_ventas.rds")
metas_mensuales <- readRDS("datos_metas.rds")

# %% [markdown]
# ## Contexto del ejercicio
#
# Una empresa de retail está analizando las ventas realizadas durante el primer semestre del año. La información disponible corresponde a distintas categorías comerciales: _Electronica, Hogar, Vestuario, Deportes y Belleza_.
#
# Para cada categoría, las ventas se encuentran separadas según el canal por el cual fueron realizadas: Tienda, Online y Mayorista. Esta separación permite comparar el comportamiento comercial entre canales y analizar diferencias en volumen de ventas, productos vendidos, regiones, descuentos aplicados y tipo de cliente.
#
# Cada registro representa una venta realizada en un mes determinado. En cada venta se identifica el producto vendido, el vendedor asociado, la región, la cantidad de unidades vendidas, el precio unitario, el descuento aplicado y si el cliente corresponde a un cliente nuevo o recurrente.
#
# Además, se dispone de una matriz de metas mensuales por región, expresadas en millones de pesos, que permite comparar el desempeño comercial observado contra ciertos objetivos definidos para cada mes del semestre.
#
# El objetivo del ejercicio es explorar, manipular y analizar estos datos utilizando herramientas básicas de R. Para ello, se trabajará con operaciones de inspección, extracción, filtrado, creación de variables, consolidación de datos y cálculo de indicadores simples.

# %% [markdown]
# A continuación se describen los campos que econtrará en el objeto `ventas`. Esta información es referencial.
#
# ## Descripción de campos
#
# | Campo             | Descripción                                                                                                                 |
# | ----------------- | --------------------------------------------------------------------------------------------------------------------------- |
# | `id_venta`        | Identificador único de cada venta registrada. Incluye referencias abreviadas a la categoría y al canal de venta.            |
# | `producto`        | Nombre del producto vendido.                                                                                                |
# | `vendedor`        | Código del vendedor asociado a la venta.                                                                                    |
# | `region`          | Región donde se realizó la venta. Puede tomar valores como `RM`, `Norte`, `Centro` o `Sur`.                                 |
# | `unidades`        | Cantidad de unidades vendidas en la transacción.                                                                            |
# | `precio_unitario` | Precio de venta de una unidad del producto.                                                                                 |
# | `descuento_pct`   | Porcentaje de descuento aplicado a la venta. Por ejemplo, `0.10` representa un descuento del 10%.                           |
# | `mes`             | Mes en que se realizó la venta. Considera los meses del primer semestre: `Ene`, `Feb`, `Mar`, `Abr`, `May` y `Jun`.         |
# | `tipo_cliente`    | Tipo de cliente asociado a la venta. Puede ser `Nuevo` o `Recurrente`.                                                      |
# |

# %% [markdown]
# # Sección 1: Exploración de objetos simples y estructuras anidadas
#
# El objeto `ventas` contiene información sintética de ventas de una tienda minorista. Considerando dicha variable responda lo siguiente.

# %% [markdown]
# ## Pregunta 1.1: Exploración inicial de la lista `ventas`
#
# **1a) (1 pt)** ¿Qué clase de objeto es `ventas`?
# **1b) (1 pt)** ¿Cuántos elementos posee `ventas`?
# **1c) (1 pt)** ¿Cuáles son los nombres de los elementos del primer nivel de `ventas`?
# **1d) (2 pts)** ¿Qué clase de objeto está almacenado en `ventas$Electronica` y cuántos elementos posee?
# **1e) (2 pts)** ¿Qué clase de objeto está almacenado en `ventas$Electronica$Online` y cuál es su dimensión?
# **1f) (1 pt)** ¿Cuáles son los nombres de las columnas de `ventas$Electronica$Online`?

# %%
# Respuesta Pregunta 1.1

# %% [markdown]
# ## Pregunta 1.2: Extracción de data.frames y creación de nuevas columnas
#
# **2a) (4 pts)** Para cada canal de la categoría `Electronica` (`Tienda`, `Online`, `Mayorista`), indique cuántas ventas corresponden al producto `Laptop`. Luego indique en qué canal se registró la mayor cantidad de ventas de `Laptop` y cuántas ventas de `Laptop` hubo en total en la categoría `Electronica`.
#
# **2b) (3 pts)** Genere tres nuevas variables llamadas `Hogar_Tienda`, `Hogar_Online` y `Hogar_Mayorista`, que contengan los data.frames de cada canal de venta para la categoría `Hogar`.
#
# **2c) (3 pts)** Para cada uno de los tres data.frames anteriores, genere una nueva columna llamada `canal`, que repita el canal correspondiente en todas sus filas.
#
# **2d) (3 pts)** Para cada uno de los tres data.frames anteriores, genere una nueva columna llamada `ingreso_bruto`, calculada como `unidades * precio_unitario`.

# %%
# Respuesta Pregunta 1.2

# %% [markdown]
# ## Pregunta 1.3: Unión de data.frames y cálculos descriptivos
#
# **3a) (3 pts)** Una las filas de `Hogar_Tienda`, `Hogar_Online` y `Hogar_Mayorista` utilizando `rbind()`. Guarde el resultado en una variable llamada `Hogar`. Luego agregue una nueva columna llamada `categoria`, cuyo valor sea `"Hogar"` para todas las filas. <br>
# **NOTA:** Su dataframe debe tener la siguiente estructura (imagen referencial).<br>
#
# ![image.png](data:image/png;base64,...)
#
# **3b) (2 pts)** ¿Cuántos productos distintos hay en el data.frame `Hogar`?
#
# **3c) (4 pts)** ¿Cuál es el ingreso bruto promedio para cada canal de venta en `Hogar`?. Puede considerar el uso de la función `mean()`
#
# **3d) (4 pts)** Considerando solo las ventas del canal `Online`, ¿cuál es el promedio de unidades vendidas por región (`RM`, `Norte`, `Centro`, `Sur`)?
#
# **3e) (3 pts)** ¿Cuántas ventas corresponden a clientes `Recurrente`, de la región `Sur`, con descuento mayor o igual a `0.10`?

# %%
# Respuesta Pregunta 1.3

# %% [markdown]
# ## Pregunta 1.4: Trabajo con matrices
#
# El objeto `metas_mensuales` es una matriz que contiene metas de venta por región y mes, expresadas en millones de pesos.
#
# **4a) (1 pt)** ¿Qué clase de objeto es `metas_mensuales`?
# **4b) (1 pt)** ¿Cuál es su dimensión?
# **4c) (2 pts)** Extraiga la meta de la región `Sur` para el mes de `Abr`.
# **4d) (3 pts)** Calcule la meta total acumulada de cada región durante los seis meses.
# **4e) (3 pts)** Calcule la meta total del mes de `Mar` considerando todas las regiones.

# %%
# Respuesta Pregunta 1.4

# %% [markdown]
# # Sección 2: Consolidación y resumen de datos
#
# En esta sección se busca consolidar toda la información disponible en la lista `ventas` en un único data.frame para luego generar indicadores descriptivos.

# %% [markdown]
# ## Pregunta 2.1: Consolidación general
#
# **1a) (8 pts)** Genere un único data.frame llamado `ventas_df` que consolide todos los registros disponibles en `ventas`.
#
# El data.frame final debe incluir, además de las columnas originales, las siguientes columnas:
#
# - `canal`: canal de venta correspondiente a cada registro.
# - `ingreso_bruto`: resultado de `unidades * precio_unitario`.
# - `categoria`: categoría de producto correspondiente a cada registro.
#
#  El data.frame final debe tener **4030 filas y 12 columnas**.

# %%
# Respuesta Pregunta 2.1

# %% [markdown]
# ## Pregunta 2.2: Resumen de ventas por categoría
#
# **2a) (10 pts)** Se le pide caracterizar las ventas del canal `Online` para las siguientes categorías:
#
# - `Electronica`
# - `Hogar`
# - `Deportes`
#
# Para cada categoría, considerando solo ventas del canal `Online`, indique:
#
# 1. Cantidad de ventas registradas.
# 2. Ingreso bruto promedio.
# 3. Producto asociado a la venta con mayor ingreso bruto.
# 4. Cantidad de ventas registradas de ese producto.
# 5. Producto asociado a la venta con menor ingreso bruto.
# 6. Cantidad de ventas registradas de ese producto.
#
# **2b) (4 pts)** Construya un data.frame llamado `resumen_online` que contenga las métricas anteriores. El data.frame debe tener una fila por categoría y columnas descriptivas para cada métrica.
#
# **2c) (2 pts)** Escriba el data.frame `resumen_online` en un archivo llamado `resumen_online.csv` utilizando `write.csv()` y sin guardar nombres de filas.

# %%
# Respuesta Pregunta 2.2
